# %% [markdown]
# ## AOI Anuradhapura

# %%
import geopandas as gpd
import os

# %%
# Path to the GADM file
gadm_path = "../AOI/gadm41_LKA.gpkg"

# Load the district/division level layer (ADM_ADM_2)
gdf = gpd.read_file(gadm_path, layer="ADM_ADM_2")

print(f"Loaded {len(gdf)} administrative divisions from Sri Lanka")
print(f"Columns: {list(gdf.columns)}")

# Filter for Anuradhapura province (all divisions within Anuradhapura)
mask = gdf["NAME_1"].str.lower().str.contains("anuradhapura", na=False)
aoi = gdf[mask].to_crs("EPSG:4326")  # ensure WGS84

print(f"\nFound {len(aoi)} divisions in Anuradhapura province:")
for division in sorted(aoi['NAME_2'].tolist()):
    print(f"  - {division}")

# Save as GeoJSON for your pipeline
out_path = "../AOI/Anuradhapura_District_AOI.geojson"
os.makedirs(os.path.dirname(out_path), exist_ok=True)
aoi.to_file(out_path, driver="GeoJSON")
print(f"\n✅ Saved Anuradhapura AOI → {out_path}")
print(f"   Area of Interest contains {len(aoi)} administrative divisions")
# Out:
# Loaded 323 administrative divisions from Sri Lanka
# Columns: ['GID_2', 'GID_0', 'COUNTRY', 'GID_1', 'NAME_1', 'NL_NAME_1', 'NAME_2', 'VARNAME_2', 'NL_NAME_2', 'TYPE_2', 'ENGTYPE_2', 'CC_2', 'HASC_2', 'geometry']
#
# Found 22 divisions in Anuradhapura province:
#   - Galenbindunuwewa
#   - Galnewa
#   - Horowpothana
#   - Ipalogama
#   - Kahatagasdigiliya
#   - Kebithigollewa
#   - Kekirawa
#   - Maha Vilachchiya
#   - Medawachchiya
#   - Mihinthale
#   - N. Palatha Central
#   - N. Palatha East
#   - Nachchadoowa
#   - Nochchiyagama
#   - Padaviya
#   - Palagala
#   - Palugaswewa
#   - Rajanganaya
#   - Rambewa
#   - Thalawa
#   - Thambuttegama
#   - Thirappane
#
# ✅ Saved Anuradhapura AOI → ../AOI/Anuradhapura_District_AOI.geojson
#    Area of Interest contains 22 administrative divisions
